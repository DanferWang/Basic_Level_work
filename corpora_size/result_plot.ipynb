# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# kappa
x = ['100M', '5.7M', '2.4M', '1M']
BNC = [0.714009, 0.712823, 0.709009, 0.698233]
CHILDS = [np.nan , 0.660334, 0.683559, 0.685825]
CABNC = [np.nan, np.nan, 0.699077, 0.685486]
KBNC = [np.nan, np.nan, np.nan, 0.691517]
NGrams = [0.677357, 0.677357, 0.677357, 0.677357]

fig, ax = plt.subplots()
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')
ax.plot(x, NGrams, label='NGrams', marker='.', color='#F08BB4')

ax.set(xlabel='Corpora size', ylabel='kappa', ylim=[0.65, 0.72])

fig.legend()
plt.show()

# %%
# balanced accuracy
x = ['100M', '5.7M', '2.4M', '1M']
BNC = [0.859528, 0.860965, 0.860044, 0.853742]
CHILDS = [np.nan , 0.840341, 0.853283, 0.854018]
CABNC = [np.nan, np.nan, 0.853742, 0.851834]
KBNC = [np.nan, np.nan, np.nan, 0.85023]
NGrams = [0.838679, 0.838679, 0.838679, 0.838679]

fig, ax = plt.subplots()
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')
ax.plot(x, NGrams, label='NGrams', marker='.', color='#F08BB4')

ax.set(xlabel='Corpora size', ylabel='balanced accuracy', ylim=[0.80, 0.90])

fig.legend()
plt.show()
