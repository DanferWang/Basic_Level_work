# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# kappa
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [0.687879, 0.684052, 0.689859, 0.686256]
CHILDS = [0.665358, 0.669301, 0.673659, np.nan]
CABNC = [0.674959, 0.687207, np.nan, np.nan]
KBNC = [0.687594, np.nan, np.nan, np.nan]
NGrams = [0.677357, 0.677357, 0.677357, 0.677357]

fig, ax = plt.subplots()
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')
ax.plot(x, NGrams, label='NGrams', marker='.', color='#F08BB4')

ax.set(xlabel='Corpora size', ylabel='kappa', ylim=[0.65, 0.72])

fig.legend()
plt.show()

# %%
# balanced accuracy
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [0.846003, 0.849977, 0.851492, 0.847429]
CHILDS = [0.842183, 0.843092, 0.844433, np.nan]
CABNC = [0.838758, 0.847429, np.nan, np.nan]
KBNC = [0.850898, np.nan, np.nan, np.nan]
NGrams = [0.838679, 0.838679, 0.838679, 0.838679]

fig, ax = plt.subplots()
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')
ax.plot(x, NGrams, label='NGrams', marker='.', color='#F08BB4')

ax.set(xlabel='Corpora size', ylabel='balanced accuracy', ylim=[0.82, 0.87])

fig.legend()
plt.show()

# %% [markdown]
# ## 50 times samplings

# %% [markdown]
# ### GlobalModel test

# %%
# KBNC
kbnc_res = np.load('./several_times_sampling/GlobalModelTest/50_times_sampling_KBNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(kbnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

kbnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
kbnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()

(kbnc_1m_kappa, kbnc_1m_acc)
# Out:
# (0.6861733470755769, 0.8483541295306002)

# %%
np.array(kappa_df).transpose().mean()
# Out:
# 0.6861733470755769

# %%
# CABNC
cabnc_res = np.load('./several_times_sampling/GlobalModelTest/50_times_sampling_CABNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(cabnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

cabnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
cabnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
cabnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
cabnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()

(cabnc_1m_kappa, cabnc_2_4m_kappa, cabnc_1m_acc, cabnc_2_4m_acc)
# Out:
# (0.6738163159989214,
#  0.6720510927996629,
#  0.8402718360071302,
#  0.8397767534874646)

# %%
cabnc_1m_kappa
# Out:
# 0.6738163159989214

# %%
# CHILDES
childes_res = np.load('./several_times_sampling/GlobalModelTest/50_times_sampling_CHILDES.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(childes_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

childes_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
childes_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
childes_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
childes_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
childes_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
childes_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()

(childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc)
# Out:
# (0.6666012120345803,
#  0.6735540523498623,
#  0.6747303011031337,
#  0.8408759943597522,
#  0.845188580271548,
#  0.8455414283307172)

# %%
# BNC
bnc_res = np.load('./several_times_sampling/GlobalModelTest/50_times_sampling_BNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(bnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

bnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
bnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
bnc_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
bnc_100m_kappa = np.array(kappa_df[3:4]).transpose().mean()
bnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
bnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
bnc_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()
bnc_100m_acc = np.array(balanced_acc_df[3:4]).transpose().mean()

(bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa, bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc)
# Out:
# (0.679993392136769,
#  0.6748565446360764,
#  0.6753689289508545,
#  0.6892689690743663,
#  0.8434948120360763,
#  0.8425786752511951,
#  0.8422799726855916,
#  0.8494967719335585)

# %%
# kappa
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa]
CHILDS = [childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, np.nan]
CABNC = [cabnc_1m_kappa, cabnc_2_4m_kappa, np.nan, np.nan]
KBNC = [kbnc_1m_kappa, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='kappa', ylim=[0.66, 0.70])

fig.legend()

plt.savefig('./readme.assets/updated_50samplings_avg_kappa.png')
plt.show()

# %%
# balanced accuracy
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc]
CHILDS = [childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc, np.nan]
CABNC = [cabnc_1m_acc, cabnc_2_4m_acc, np.nan, np.nan]
KBNC = [kbnc_1m_acc, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='balanced accuracy', ylim=[0.83, 0.86])

fig.legend()

plt.savefig('./readme.assets/updated_50samplings_avg_balancedacc.png')
plt.show()

# %% [markdown]
# ### LocalModel

# %%
# KBNC
kbnc_res = np.load('./several_times_sampling/LocalModelTest/LocalModel_inte_50_times_sampling_KBNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(kbnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

kbnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
kbnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()

(kbnc_1m_kappa, kbnc_1m_acc)
# Out:
# (0.6330520225934702, 0.8266203170359054)

# %%
# CABNC
cabnc_res = np.load('./several_times_sampling/LocalModelTest/LocalModel_inte_50_times_sampling_CABNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(cabnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

cabnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
cabnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
cabnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
cabnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()

(cabnc_1m_kappa, cabnc_2_4m_kappa, cabnc_1m_acc, cabnc_2_4m_acc)
# Out:
# (0.642962380925753, 0.6447328639267833, 0.8285752094474154, 0.8329210816144639)

# %%
# CHILDES
childes_res = np.load('./several_times_sampling/LocalModelTest/LocalModel_inte_50_times_sampling_CHILDES.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(childes_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

childes_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
childes_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
childes_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
childes_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
childes_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
childes_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()

(childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc)
# Out:
# (0.6432416592931449,
#  0.6467070662369241,
#  0.6487532374504688,
#  0.8301280322128852,
#  0.8315449045072576,
#  0.8326571103896103)

# %%
# BNC
bnc_res = np.load('./several_times_sampling/LocalModelTest/LocalModel_inte_50_times_sampling_BNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(bnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

bnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
bnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
bnc_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
bnc_100m_kappa = np.array(kappa_df[3:4]).transpose().mean()
bnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
bnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
bnc_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()
bnc_100m_acc = np.array(balanced_acc_df[3:4]).transpose().mean()

(bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa, bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc)
# Out:
# (0.6504575224065953,
#  0.6568882951808093,
#  0.6551882488984994,
#  0.661968217247781,
#  0.8333237776928953,
#  0.8366845409982174,
#  0.8369791660300484,
#  0.8419098612172141)

# %%
# kappa
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa]
CHILDS = [childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, np.nan]
CABNC = [cabnc_1m_kappa, cabnc_2_4m_kappa, np.nan, np.nan]
KBNC = [kbnc_1m_kappa, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='kappa', ylim=[0.63, 0.67])

fig.legend()

plt.savefig('./readme.assets/LocalModel_50samplings_avg_kappa.png')
plt.show()

# %%
# balanced accuracy
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc]
CHILDS = [childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc, np.nan]
CABNC = [cabnc_1m_acc, cabnc_2_4m_acc, np.nan, np.nan]
KBNC = [kbnc_1m_acc, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='balanced accuracy', ylim=[0.82, 0.85])

fig.legend()

plt.savefig('./readme.assets/LocalModel_50samplings_avg_balancedacc.png')
plt.show()

# %% [markdown]
# ### TransferModel

# %%
# KBNC
kbnc_res = np.load('./several_times_sampling/TransferModelTest/TransferModel_inte_50_times_sampling_KBNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(kbnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

kbnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
kbnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()

(kbnc_1m_kappa, kbnc_1m_acc)
# Out:
# (0.5307345665772614, 0.8098576543780506)

# %%
# CABNC
cabnc_res = np.load('./several_times_sampling/TransferModelTest/TransferModel_inte_50_times_sampling_CABNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(cabnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

cabnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
cabnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
cabnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
cabnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()

(cabnc_1m_kappa, cabnc_2_4m_kappa, cabnc_1m_acc, cabnc_2_4m_acc)
# Out:
# (0.5104943499649217,
#  0.5158076807339844,
#  0.7961279664980495,
#  0.7988248650961516)

# %%
# CHILDES
childes_res = np.load('./several_times_sampling/TransferModelTest/TransferModel_inte_50_times_sampling_CHILDES.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(childes_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

childes_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
childes_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
childes_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
childes_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
childes_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
childes_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()

(childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc)
# Out:
# (0.5235977740741911,
#  0.5208352247434407,
#  0.5176270278980081,
#  0.8085240579452183,
#  0.8083335230915705,
#  0.8063044465957865)

# %%
# BNC
bnc_res = np.load('./several_times_sampling/TransferModelTest/TransferModel_inte_50_times_sampling_BNC.npy', allow_pickle=True).item()
res_df = pd.DataFrame.from_dict(bnc_res)
kappa_df = pd.DataFrame()
balanced_acc_df = pd.DataFrame()
for index, row in res_df.iterrows():
    for counter in range(50):
        kappa_df.at[index, counter] = row[counter]['kappa']
        balanced_acc_df.at[index, counter] = row[counter]['balanced acc']

bnc_1m_kappa = np.array(kappa_df[0:1]).transpose().mean()
bnc_2_4m_kappa = np.array(kappa_df[1:2]).transpose().mean()
bnc_5_7m_kappa = np.array(kappa_df[2:3]).transpose().mean()
bnc_100m_kappa = np.array(kappa_df[3:4]).transpose().mean()
bnc_1m_acc = np.array(balanced_acc_df[0:1]).transpose().mean()
bnc_2_4m_acc = np.array(balanced_acc_df[1:2]).transpose().mean()
bnc_5_7m_acc = np.array(balanced_acc_df[2:3]).transpose().mean()
bnc_100m_acc = np.array(balanced_acc_df[3:4]).transpose().mean()

(bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa, bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc)
# Out:
# (0.5320453733398239,
#  0.539353041700657,
#  0.5427527947057473,
#  0.5558330397564571,
#  0.8114755281447011,
#  0.8146521057110064,
#  0.8157673683320145,
#  0.8141179476012063)

# %%
# kappa
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_kappa, bnc_2_4m_kappa, bnc_5_7m_kappa, bnc_100m_kappa]
CHILDS = [childes_1m_kappa, childes_2_4m_kappa, childes_5_7m_kappa, np.nan]
CABNC = [cabnc_1m_kappa, cabnc_2_4m_kappa, np.nan, np.nan]
KBNC = [kbnc_1m_kappa, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='kappa', ylim=[0.50, 0.56])

fig.legend(loc=5)

plt.savefig('./readme.assets/TransferModel_50samplings_avg_kappa.png')
plt.show()

# %%
# balanced accuracy
x = ['1M', '2.4M', '5.7M', '100M']
BNC = [bnc_1m_acc, bnc_2_4m_acc, bnc_5_7m_acc, bnc_100m_acc]
CHILDS = [childes_1m_acc, childes_2_4m_acc, childes_5_7m_acc, np.nan]
CABNC = [cabnc_1m_acc, cabnc_2_4m_acc, np.nan, np.nan]
KBNC = [kbnc_1m_acc, np.nan, np.nan, np.nan]

fig, ax = plt.subplots()
fig.set_figwidth(6)
fig.set_facecolor('white')
ax.plot(x, BNC, label='BNC', marker='.', color='#5B8FF9')
ax.plot(x, CHILDS, label='CHILDS', marker='.', color='#61DDAA')
ax.plot(x, CABNC, label='CABNC', marker='.', color='#F6BD16')
ax.plot(x, KBNC, label='KBNC', marker='.', color='#9661BC')

ax.set(xlabel='Corpora size', ylabel='balanced accuracy', ylim=[0.79, 0.82])

fig.legend()

plt.savefig('./readme.assets/TransferModel_50samplings_avg_balancedacc.png')
plt.show()
